# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df=pd.read_csv("Salary Data.csv")
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
#checking duplicates
sum(df.duplicated(subset = 'Gender')) == 0
# No duplicate values
# Out:
# False

# %%
# Checking Null values
df.isnull().sum()
# There are no NULL values in the dataset, hence it is clean.
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
# Checking Null values
df.isnull().sum()
# There are no NULL values in the dataset, hence it is clean.
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
#no of children pie plot
df_sym = pd.DataFrame(df['Education Level'].value_counts())
print(df_sym.index.values)
df_sym.plot.pie(subplots=True,labels = df_sym.index.values, autopct='%1.2f%%', figsize = (15,7.5))
# # Unsquish the pie.
# # plt.gca().set_aspect('equal')
# plt.show()
# # plt.tight_layout()
# Out:
# ["Bachelor's" "Master's" 'PhD']
# array([<Axes: ylabel='count'>], dtype=object)

# %%
#region vs expenses barplot
print(df[['Gender','Salary']].groupby("Gender").mean())  # sum() can also be used

plt1 = df[['Gender','Salary']].groupby("Gender").mean().plot(kind='bar',legend = True,)
plt1.set_xlabel("Gender")
plt1.set_ylabel("Avg Salary (Dollars)")
xticks(rotation = 90)
plt.show()
# Out:
#                Salary
# Gender
# Female   97011.173184
# Male    103867.783505

# %%
#region vs avg no of children
df_comp_avg_price = df[['Education Level','Salary']].groupby("Education Level", as_index = False).mean().rename(columns={'children':'no. of children'})
print(df_comp_avg_price)


plt1 = df_comp_avg_price.plot(x = 'Education Level', kind='bar',legend = True, sort_columns = True, figsize = (15,3))
plt1.set_xlabel("Education Level")
plt1.set_ylabel("Avg Salary")
xticks(rotation = 90)
plt.show()
# Out:
#   Education Level         Salary
# 0      Bachelor's   74756.026786
# 1        Master's  129795.918367
# 2             PhD  157843.137255
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 6
#       2 df_comp_avg_price = df[['Education Level','Salary']].groupby("Education Level", as_index = False).mean().rename(columns={'children':'no. of children'})
#       3 print(df_comp_avg_price)
# ----> 6 plt1 = df_comp_avg_price.plot(x = 'Education Level', kind='bar',legend = True, sort_columns = True, figsize = (15,3))
#       7 plt1.set_xlabel("Education Level")
#       8 plt1.set_ylabel("Avg Salary")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# ...

# %%
#no of children vs avg charges

df_comp_avg_price = df[['Years of Experience','Salary']].groupby("Years of Experience", as_index = False).mean()
print(df_comp_avg_price)
plt1 = df_comp_avg_price.plot(x = 'Years of Experience', kind='bar',legend = True, sort_columns = True, figsize = (15,3))
plt1.set_xlabel("Years of Experience")
plt1.set_ylabel("Avg Salary ")
xticks(rotation = 90)
plt.show()
# Out:
#     Years of Experience         Salary
# 0                   0.0   33333.333333
# 1                   0.5   35000.000000
# 2                   1.0   37857.142857
# 3                   1.5   36279.166667
# 4                   2.0   41774.193548
# 5                   3.0   51166.666667
# 6                   4.0   58500.000000
# 7                   5.0   64117.647059
# 8                   6.0   83750.000000
# 9                   7.0   84444.444444
# 10                  8.0   88800.000000
# 11                  9.0  101818.181818
# 12                 10.0  100555.555556
# 13                 11.0  100500.000000
# 14                 12.0  105000.000000
# 15                 13.0  120000.000000
# 16                 14.0  125769.230769
# 17                 15.0  134375.000000
# 18                 16.0  157500.000000
# 19                 17.0  143000.000000
# 20                 18.0  149615.384615
# 21                 19.0  166333.333333
# 22                 20.0  168846.153846
# ...

# %%
auto=df[['Age','Gender','Education Level','Years of Experience','Salary']]
auto
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
# #no of children vs avg charges

# df_comp_avg_price = df[['Job Title','Salary']].groupby("Job Title", as_index = False).mean()
# print(df_comp_avg_price)
# plt1 = df_comp_avg_price.plot(x = 'Job Title', kind='bar',legend = True, sort_columns = True, figsize = (15,3))
# plt1.set_xlabel("Years of Experience")
# plt1.set_ylabel("Avg Salary ")
# xticks(rotation = 90)
# plt.show()

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(auto)
plt.show()
# Out:
# C:\Users\Nar Een\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Dimension Reduction
gender = pd.get_dummies(auto['Gender'], drop_first = True)

# %%
auto = pd.concat([auto, gender], axis = 1)
auto
# Out:
#       Age  Gender Education Level  Years of Experience    Salary   Male
# 0    32.0    Male      Bachelor's                  5.0   90000.0   True
# 1    28.0  Female        Master's                  3.0   65000.0  False
# 2    45.0    Male             PhD                 15.0  150000.0   True
# 3    36.0  Female      Bachelor's                  7.0   60000.0  False
# 4    52.0    Male        Master's                 20.0  200000.0   True
# ..    ...     ...             ...                  ...       ...    ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0  False
# 371  43.0    Male        Master's                 19.0  170000.0   True
# 372  29.0  Female      Bachelor's                  2.0   40000.0  False
# 373  34.0    Male      Bachelor's                  7.0   90000.0   True
# 374  44.0  Female             PhD                 15.0  150000.0  False
#
# [373 rows x 6 columns]

# %%
region_typ = pd.get_dummies(auto['Education Level'], drop_first = True)
region_typ
# Out:
#      Master's    PhD
# 0       False  False
# 1        True  False
# 2       False   True
# 3       False  False
# 4        True  False
# ..        ...    ...
# 370     False  False
# 371      True  False
# 372     False  False
# 373     False  False
# 374     False   True
#
# [373 rows x 2 columns]

# %%
auto = pd.concat([auto, region_typ], axis = 1)
auto
# Out:
#       Age  Gender Education Level  Years of Experience    Salary   Male  \
# 0    32.0    Male      Bachelor's                  5.0   90000.0   True
# 1    28.0  Female        Master's                  3.0   65000.0  False
# 2    45.0    Male             PhD                 15.0  150000.0   True
# 3    36.0  Female      Bachelor's                  7.0   60000.0  False
# 4    52.0    Male        Master's                 20.0  200000.0   True
# ..    ...     ...             ...                  ...       ...    ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0  False
# 371  43.0    Male        Master's                 19.0  170000.0   True
# 372  29.0  Female      Bachelor's                  2.0   40000.0  False
# 373  34.0    Male      Bachelor's                  7.0   90000.0   True
# 374  44.0  Female             PhD                 15.0  150000.0  False
#
#      Master's    PhD
# 0       False  False
# 1        True  False
# 2       False   True
# ...

# %%
# smoker = pd.get_dummies(auto['Years of Experience'], drop_first = True)
# smoker

# %%
auto.drop(['Gender','Education Level'], axis = 1, inplace = True)
auto
# Out:
#       Age  Years of Experience    Salary   Male  Master's    PhD
# 0    32.0                  5.0   90000.0   True     False  False
# 1    28.0                  3.0   65000.0  False      True  False
# 2    45.0                 15.0  150000.0   True     False   True
# 3    36.0                  7.0   60000.0  False     False  False
# 4    52.0                 20.0  200000.0   True      True  False
# ..    ...                  ...       ...    ...       ...    ...
# 370  35.0                  8.0   85000.0  False     False  False
# 371  43.0                 19.0  170000.0   True      True  False
# 372  29.0                  2.0   40000.0  False     False  False
# 373  34.0                  7.0   90000.0   True     False  False
# 374  44.0                 15.0  150000.0  False     False   True
#
# [373 rows x 6 columns]

# %%
#Starting Machine Learning 
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
df_train, df_test = train_test_split(auto, train_size = 0.7, test_size = 0.3, random_state = 1)

# %%
df_train
# Out:
#       Age  Years of Experience    Salary   Male  Master's    PhD
# 146  42.0                 16.0  150000.0  False     False   True
# 222  33.0                  7.0  100000.0   True     False  False
# 119  35.0                 10.0  120000.0   True      True  False
# 80   36.0                  8.0   70000.0   True     False  False
# 88   46.0                 21.0  135000.0   True      True  False
# ..    ...                  ...       ...    ...       ...    ...
# 204  36.0                  7.0   90000.0   True     False  False
# 256  34.0                  6.0  100000.0  False      True  False
# 72   45.0                 16.0  190000.0   True     False   True
# 236  37.0                  9.0  100000.0  False     False  False
# 37   42.0                 14.0  115000.0   True      True  False
#
# [261 rows x 6 columns]

# %%
df_test
# Out:
#       Age  Years of Experience    Salary   Male  Master's    PhD
# 67   31.0                  5.0   45000.0  False     False  False
# 348  28.0                  1.0   35000.0  False     False  False
# 343  41.0                 14.0  150000.0   True     False  False
# 295  33.0                  4.0   60000.0   True     False  False
# 90   36.0                 11.0  120000.0   True     False   True
# ..    ...                  ...       ...    ...       ...    ...
# 247  31.0                  3.0   50000.0   True     False  False
# 162  30.0                  3.0   45000.0  False     False  False
# 209  30.0                  2.0   40000.0  False     False  False
# 122  33.0                  5.0   50000.0  False     False  False
# 336  29.0                  2.0   40000.0  False     False  False
#
# [112 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
df_train.head()
# Out:
#       Age  Years of Experience    Salary   Male  Master's    PhD
# 146  42.0                 16.0  150000.0  False     False   True
# 222  33.0                  7.0  100000.0   True     False  False
# 119  35.0                 10.0  120000.0   True      True  False
# 80   36.0                  8.0   70000.0   True     False  False
# 88   46.0                 21.0  135000.0   True      True  False

# %%
# Apply scaler() to all the columns except the 'dummy' variables
num_vars = ['Age', 'Years of Experience', 'Salary']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#           Age  Years of Experience    Salary   Male  Master's    PhD
# 146  0.633333                 0.64  0.599439  False     False   True
# 222  0.333333                 0.28  0.399159   True     False  False
# 119  0.400000                 0.40  0.479271   True      True  False
# 80   0.433333                 0.32  0.278991   True     False  False
# 88   0.766667                 0.84  0.539355   True      True  False

# %%
df_train.describe()
# Out:
#               Age  Years of Experience      Salary
# count  261.000000           261.000000  261.000000
# mean     0.474074             0.395326    0.401696
# std      0.230432             0.257648    0.190392
# min      0.000000             0.000000    0.000000
# 25%      0.300000             0.160000    0.238935
# 50%      0.433333             0.360000    0.379131
# 75%      0.666667             0.600000    0.519327
# max      1.000000             1.000000    1.000000

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True,)
plt.show()

# %%
y_train = df_train.pop('Salary')
X_train = df_train

# %%
y_train
# Out:
# 146    0.599439
# 222    0.399159
# 119    0.479271
# 80     0.278991
# 88     0.539355
#          ...
# 204    0.359103
# 256    0.399159
# 72     0.759664
# 236    0.399159
# 37     0.459243
# Name: Salary, Length: 261, dtype: float64

# %%
X_train
# Out:
#           Age  Years of Experience   Male  Master's    PhD
# 146  0.633333                 0.64  False     False   True
# 222  0.333333                 0.28   True     False  False
# 119  0.400000                 0.40   True      True  False
# 80   0.433333                 0.32   True     False  False
# 88   0.766667                 0.84   True      True  False
# ..        ...                  ...    ...       ...    ...
# 204  0.433333                 0.28   True     False  False
# 256  0.366667                 0.24  False      True  False
# 72   0.733333                 0.64   True     False   True
# 236  0.466667                 0.36  False     False  False
# 37   0.633333                 0.56   True      True  False
#
# [261 rows x 5 columns]

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()
# lm.fit(X_train, y_train)

#rfe = RFE(lm, 10)
rfe = RFE(lm, n_features_to_select=10)
#running RFE
rfe = rfe.fit(X_train, y_train)

# %%
X_train.columns
# Out:
# Index(['Age', 'Years of Experience', 'Male', 'Master's', 'PhD'], dtype='object')

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Age', True, 1),
#  ('Years of Experience', True, 1),
#  ('Male', True, 1),
#  ("Master's", True, 1),
#  ('PhD', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['Age', 'Years of Experience', 'Male', 'Master's', 'PhD'], dtype='object')

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
X_train_rfe
# Out:
#           Age  Years of Experience   Male  Master's    PhD
# 146  0.633333                 0.64  False     False   True
# 222  0.333333                 0.28   True     False  False
# 119  0.400000                 0.40   True      True  False
# 80   0.433333                 0.32   True     False  False
# 88   0.766667                 0.84   True      True  False
# ..        ...                  ...    ...       ...    ...
# 204  0.433333                 0.28   True     False  False
# 256  0.366667                 0.24  False      True  False
# 72   0.733333                 0.64   True     False   True
# 236  0.466667                 0.36  False     False  False
# 37   0.633333                 0.56   True      True  False
#
# [261 rows x 5 columns]

# %%
# Adding a constant variable
import statsmodels.api as sm
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
X_train_rfe
# Out:
#      const       Age  Years of Experience   Male  Master's    PhD
# 146    1.0  0.633333                 0.64  False     False   True
# 222    1.0  0.333333                 0.28   True     False  False
# 119    1.0  0.400000                 0.40   True      True  False
# 80     1.0  0.433333                 0.32   True     False  False
# 88     1.0  0.766667                 0.84   True      True  False
# ..     ...       ...                  ...    ...       ...    ...
# 204    1.0  0.433333                 0.28   True     False  False
# 256    1.0  0.366667                 0.24  False      True  False
# 72     1.0  0.733333                 0.64   True     False   True
# 236    1.0  0.466667                 0.36  False     False  False
# 37     1.0  0.633333                 0.56   True      True  False
#
# [261 rows x 6 columns]

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()  # Running the linear model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 lm = sm.OLS(y_train,X_train_rfe).fit()
#
# File ~\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
#     923                           hasconst=hasconst, **kwargs)
#     924 if "weights" in self._init_keys:
#     925     self._init_keys.remove("weights")
#
# File ~\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:748, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     746 else:
# ...

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 #Let's see the summary of our linear model
# ----> 2 print(lm.summary())
#
# AttributeError: 'LinearRegression' object has no attribute 'summary'

# %%
df_test
# Out:
#       Age  Years of Experience    Salary   Male  Master's    PhD
# 67   31.0                  5.0   45000.0  False     False  False
# 348  28.0                  1.0   35000.0  False     False  False
# 343  41.0                 14.0  150000.0   True     False  False
# 295  33.0                  4.0   60000.0   True     False  False
# 90   36.0                 11.0  120000.0   True     False   True
# ..    ...                  ...       ...    ...       ...    ...
# 247  31.0                  3.0   50000.0   True     False  False
# 162  30.0                  3.0   45000.0  False     False  False
# 209  30.0                  2.0   40000.0  False     False  False
# 122  33.0                  5.0   50000.0  False     False  False
# 336  29.0                  2.0   40000.0  False     False  False
#
# [112 rows x 6 columns]

# %%
num_vars = ['Age', 'Years of Experience', 'Salary']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test
# Out:
#           Age  Years of Experience    Salary   Male  Master's    PhD
# 67   0.266667                 0.20  0.178850  False     False  False
# 348  0.166667                 0.04  0.138794  False     False  False
# 343  0.600000                 0.56  0.599439   True     False  False
# 295  0.333333                 0.16  0.238935   True     False  False
# 90   0.433333                 0.44  0.479271   True     False   True
# ..        ...                  ...       ...    ...       ...    ...
# 247  0.266667                 0.12  0.198878   True     False  False
# 162  0.233333                 0.12  0.178850  False     False  False
# 209  0.233333                 0.08  0.158822  False     False  False
# 122  0.333333                 0.20  0.198878  False     False  False
# 336  0.200000                 0.08  0.158822  False     False  False
#
# [112 rows x 6 columns]

# %%
y_test = df_test.pop('Salary')
X_test = df_test

# %%
y_test
# Out:
# 67     0.178850
# 348    0.138794
# 343    0.599439
# 295    0.238935
# 90     0.479271
#          ...
# 247    0.198878
# 162    0.178850
# 209    0.158822
# 122    0.198878
# 336    0.158822
# Name: Salary, Length: 112, dtype: float64

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[['Age','Years of Experience','Male']]

X_test_new
# Out:
#           Age  Years of Experience   Male
# 67   0.266667                 0.20  False
# 348  0.166667                 0.04  False
# 343  0.600000                 0.56   True
# 295  0.333333                 0.16   True
# 90   0.433333                 0.44   True
# ..        ...                  ...    ...
# 247  0.266667                 0.12   True
# 162  0.233333                 0.12  False
# 209  0.233333                 0.08  False
# 122  0.333333                 0.20  False
# 336  0.200000                 0.08  False
#
# [112 rows x 3 columns]

# %%
# Adding a constant variable
X_test_new = sm.add_constant(X_test_new)
X_test_new
# Out:
#      const       Age  Years of Experience   Male
# 67     1.0  0.266667                 0.20  False
# 348    1.0  0.166667                 0.04  False
# 343    1.0  0.600000                 0.56   True
# 295    1.0  0.333333                 0.16   True
# 90     1.0  0.433333                 0.44   True
# ..     ...       ...                  ...    ...
# 247    1.0  0.266667                 0.12   True
# 162    1.0  0.233333                 0.12  False
# 209    1.0  0.233333                 0.08  False
# 122    1.0  0.333333                 0.20  False
# 336    1.0  0.200000                 0.08  False
#
# [112 rows x 4 columns]

# %%
# Making predictions
y_pred = lm.predict(X_test_new)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 # Making predictions
# ----> 2 y_pred = lm.predict(X_test_new)
#       3 y_pred
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:367, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
# --> 367     check_is_fitted(self)
#     369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
y_test
# Out:
# 67     0.178850
# 348    0.138794
# 343    0.599439
# 295    0.238935
# 90     0.479271
#          ...
# 247    0.198878
# 162    0.178850
# 209    0.158822
# 122    0.198878
# 336    0.158822
# Name: Salary, Length: 112, dtype: float64

# %%
#test aucc
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 #test aucc
#       2 from sklearn.metrics import r2_score
# ----> 3 r2_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 # Plotting y_test and y_pred to understand the spread.
#       2 fig = plt.figure()
# ----> 3 plt.scatter(y_test,y_pred)
#       4 fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
#       5 plt.xlabel('y_test', fontsize=18)                          # X-label
#
# NameError: name 'y_pred' is not defined
